# %% [markdown]
# # EDA of credit card data

# %% [markdown]
# Let's start by importing the necessary libraries. For this eda we will import numpy, pandas, matplotlb and seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now lets work on importing the data from the excel file using pandas. we will store this data in a pandas Data Frame. We will also see 5 random data points of this dataset.

# %%
data = pd.read_excel("default of credit card clients.xls", header = 1)
data.sample(5)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 2587    2588     130000    2          1         2   32      1     -2     -1
# 29003  29004     440000    2          2         2   34      0      0     -1
# 19580  19581     200000    2          2         1   39     -1     -1     -1
# 13445  13446     150000    1          1         2   29     -1      0      0
# 28557  28558     370000    2          2         1   41     -2     -2     -2
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 2587      -1  ...          0          0       1300         0      3726
# 29003      0  ...     218064     222734     227445      1000    226848
# 19580     -1  ...       9312      23958      10825     15571     21488
# 13445      0  ...     149530     146455     141711     46980     64890
# 28557     -2  ...      30100          0          0      9750         0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 2587          0         0      1300      5400                           0
# 29003      8300      8300      8300      8300                           0
# 19580      9312     23958     10825     10773                           0
# 13445    122080    106625    141711    138195                           0
# 28557     30100         0         0         0                           0
#
# [5 rows x 25 columns]

# %% [markdown]
# As you can see the data columns aren't clear. We will name them properly before doing anything else.

# %% [markdown]
# This is much more better. now as Id columns is useless, lets drop it.

# %%
data = data.drop(columns = 'ID')
data.sample(5)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 15065     590000    1          1         2   33      0      0     -1      0
# 15930     310000    2          2         1   29     -2     -2     -2     -2
# 20644     130000    1          1         1   42     -1      2     -1     -1
# 4232      150000    1          1         1   57     -2     -2     -2     -1
# 10798      70000    1          2         2   43      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 15065      0  ...      61065      30510      25887     60092     68753
# 15930     -2  ...       3024          0          0      1062      8805
# 20644      0  ...       1170       1170        780         0       955
# 4232      -1  ...       2120     143701     146318     22000      2509
# 10798      0  ...      28562      29155      29448      1586      1739
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 15065     10000     15033     25965     20377                           0
# 15930      3087         0         0      3240                           0
# 20644      1170         0         0         0                           1
# 4232       2120    143701      6000      5200                           0
# 10798      1002      1033      1142      1014                           0
#
# [5 rows x 24 columns]

# %% [markdown]
# Now let's understand the meaning of the features. After researching, I found that :
# - LIMIT_BAL: Amount of the given credit (in NT dollars).
# - SEX: Gender (1 = male; 2 = female).
# - EDUCATION: Education level (1 = graduate school; 2 = university; 3 = high school; 4 = others; 0, 5, 6 are often grouped into "others/unknown").
# - MARRIAGE: Marital status (1 = married; 2 = single; 3 = others).
# - AGE: Age in years.
# - PAY_0 (or PAY_1), PAY_2, PAY_3, PAY_4, PAY_5, PAY_6: Repayment status for each of the last six months. The values indicate the payment delay:
#   - -1 = Pay duly/on time.
#   - 0 = No delay.
#   - 1 = Payment delay for one month.
#   - 2 = Payment delay for two months, etc., up to 9 (nine months and above delay).
# - BILL_AMT1 to BILL_AMT6: Amount of bill statement for each of the last six months.
# - PAY_AMT1 to PAY_AMT6: Amount of previous payment for each of the last six months.
#
# Now as we know what every feature is, we can explore the data more properly.
# Before exploring any feature, lets see if there are any missing values.

# %%
data.isna().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# There seems to be no missing data!
